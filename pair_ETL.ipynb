# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import ttest_ind, norm, chi2_contingency
from scipy.stats import shapiro
from scipy.stats import mannwhitneyu
from sklearn.linear_model import LinearRegression

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
#Cuando se pase al soporte la ruta tiene que ser: ./files/{ruta}.csv
def leer_cvs(ruta):
    try:
        df = pd.read_csv(f'files/{ruta}.csv', error_bad_lines=False, warn_bad_lines=False)
        return df
    except FileNotFoundError:
        print('No se ha encontrado el archivo')
        return None

# %%
df_clientes = leer_cvs('clientes')
df_clientes
# Out:
#        id  first_name last_name                         email  gender  \
# 0       1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1       2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2       3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3       4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4       5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
# ..    ...         ...       ...                           ...     ...
# 995   996         Ray    Tarpey      rtarpeyrn@bravesites.com  Female
# 996   997        Flem  Roderham       froderhamro@dropbox.com    Male
# 997   998   Winifield    Blakes         wblakesrp@jiathis.com    Male
# 998   999      Lanita  Espinosa        lespinosarq@discuz.net  Female
# 999  1000     Grissel   Siberry     gsiberryrr@wikispaces.com  Female
#
#                             City Country                   Address
# 0              Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                           Lugo   Spain        0046 Utah Junction
# 2                            NaN   Spain          0 Corry Crossing
# 3                           Leon   Spain       5 American Ash Road
# 4    Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# ..                           ...     ...                       ...
# 995                       Zamora   Spain     36384 Sommers Terrace
# 996                   Pontevedra   Spain    93177 Eastwood Parkway
# 997                         Vigo   Spain       03044 Grayhawk Road
# 998                 Dos Hermanas   Spain        2 Schmedeman Drive
# 999                         Leon   Spain     42274 Waywood Terrace
#
# [1000 rows x 8 columns]

# %%
df_ventas = leer_cvs('ventas')
df_ventas
# Out:
#     ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0          723          A1  2023-11-22         2  17.98
# 1          498          C3  2023-11-21         1   5.49
# 2          121          D4  2023-11-20         3  32.97
# 3          885         L12  2023-11-19         1   6.49
# 4          347         Q17  2023-11-18         2   7.98
# ..         ...         ...         ...       ...    ...
# 95         234       AR136  2023-09-04         1   8.45
# 96         987       AS137  2023-09-03         2  12.50
# 97         543       AT138  2023-09-02         1   4.75
# 98         234       AU139  2023-09-01         2   9.98
# 99         987       AV140  2023-08-31         1   5.25
#
# [100 rows x 5 columns]

# %%
df_productos = leer_cvs('productos')
df_productos
# Out:
#                                   ID       Nombre_Producto  Categoría  Precio  \
# A1                  Pizza Margherita     Platos Preparados       8.99  Italia
# B2            Risotto de Champiñones     Platos Preparados       6.75  Italia
# C3                          Tiramisú               Postres       5.49  Italia
# D4                         Panettone            Repostería      10.99  Italia
# E5                       Orecchiette       Productos Secos       4.29  Italia
# F6               Polenta Tradicional               Harinas       3.75  Italia
# G7              Mozzarella di Bufala     Productos Lácteos       9.25  Italia
# J10                    Arroz Arborio       Productos Secos       4.89  Italia
# K11                    Café Espresso                  Café       6.49  Italia
# L12      Sardinas en Aceite de Oliva  Pescados en Conserva       3.99  Italia
# N14                Gnocchi de Patata  Productos Congelados       5.25  Italia
# O15   Ravioli de Ricotta y Espinacas  Productos Congelados       6.75  Italia
# Q17                   Pasta de Trigo       Productos Secos       3.99  Italia
# R18           Salsa de Tomate Casera                Salsas       2.49  Italia
# S19     Aceite de Oliva Virgen Extra               Aceites       9.99  Italia
# T20                  Queso Parmesano     Productos Lácteos       7.89  Italia
# U21                   Salami Toscano             Embutidos       5.75  Italia
# W23                  Gelato de Limón               Helados       4.25  Italia
# X24                          Cannoli                Dulces       3.99  Italia
# Y25                       Cacciatore             Embutidos       6.75  Italia
# GG33                   Ciceri e Tria     Platos Preparados       5.89  Italia
#
#                                                  Origen  \
# A1                    Clásica pizza italiana con tomate
# B2              Risotto cremoso con champiñones frescos
# C3    Postre clásico italiano con capas de bizcocho ...
# D4    Pan dulce navideño italiano con frutas confita...
# E5    Pequeñas pastas con forma de orecchiette ideal...
# F6    Harina de maíz italiana para preparar la tradi...
# G7      Mozzarella fresca elaborada con leche de búfala
# J10   Arroz de grano corto perfecto para risottos it...
# K11   Café espresso italiano con un aroma y sabor in...
# L12                 Sardinas frescas en aceite de oliva
# N14                          Gnocchi de patata italiana
# O15    Raviolis rellenos de ricotta y espinacas frescas
# Q17             Deliciosa pasta de trigo durum italiana
# R18             Elaborada con tomates italianos maduros
# S19   Aceite de oliva prensado en frío de las mejore...
# T20                            El famoso queso italiano
# U21   Salami de cerdo italiano curado con hierbas y ...
# W23    Gelato italiano cremoso con sabor a limón fresco
# X24   Postre siciliano con masa crujiente rellena de...
# Y25   Salchichas de cerdo condimentadas con hierbas ...
# GG33  Plato de pasta tradicional de Apulia con garba...
#
#                                             Descripción
# A1                        mozzarella fresca y albahaca.
# B2         una delicia italiana para disfrutar en casa.
# C3                         mascarpone y cacao en polvo.
# D4                     un regalo tradicional en Italia.
# E5                                                  NaN
# F6                        perfecta como acompañamiento.
# G7                      suave y deliciosamente cremosa.
# J10             absorbe los sabores de forma exquisita.
# K11        la esencia de la cultura del café en Italia.
# L12                    un bocado delicioso y saludable.
# N14                ideales con salsa de tomate o crema.
# O15                             simplemente deliciosos.
# Q17           ideal para platos de pasta tradicionales.
# R18    una receta tradicional que realza el sabor de...
# S19                   perfecto para aderezos y cocinar.
# T20    madurado durante meses para obtener su sabor ...
# U21    un acompañamiento perfecto para tablas de emb...
# W23                  un postre refrescante y delicioso.
# X24                            una delicia tradicional.
# Y25                          perfectas para aperitivos.
# GG33                             una combinación única.

# %%
def minuscula(dataframe):
    dataframe.columns = map(str.lower, dataframe.columns)
    return dataframe

# %%
minuscula(df_clientes)
minuscula(df_ventas)
minuscula(df_productos)
# Out:
#                                   id       nombre_producto  categoría  precio  \
# A1                  Pizza Margherita     Platos Preparados       8.99  Italia
# B2            Risotto de Champiñones     Platos Preparados       6.75  Italia
# C3                          Tiramisú               Postres       5.49  Italia
# D4                         Panettone            Repostería      10.99  Italia
# E5                       Orecchiette       Productos Secos       4.29  Italia
# F6               Polenta Tradicional               Harinas       3.75  Italia
# G7              Mozzarella di Bufala     Productos Lácteos       9.25  Italia
# J10                    Arroz Arborio       Productos Secos       4.89  Italia
# K11                    Café Espresso                  Café       6.49  Italia
# L12      Sardinas en Aceite de Oliva  Pescados en Conserva       3.99  Italia
# N14                Gnocchi de Patata  Productos Congelados       5.25  Italia
# O15   Ravioli de Ricotta y Espinacas  Productos Congelados       6.75  Italia
# Q17                   Pasta de Trigo       Productos Secos       3.99  Italia
# R18           Salsa de Tomate Casera                Salsas       2.49  Italia
# S19     Aceite de Oliva Virgen Extra               Aceites       9.99  Italia
# T20                  Queso Parmesano     Productos Lácteos       7.89  Italia
# U21                   Salami Toscano             Embutidos       5.75  Italia
# W23                  Gelato de Limón               Helados       4.25  Italia
# X24                          Cannoli                Dulces       3.99  Italia
# Y25                       Cacciatore             Embutidos       6.75  Italia
# GG33                   Ciceri e Tria     Platos Preparados       5.89  Italia
#
#                                                  origen  \
# A1                    Clásica pizza italiana con tomate
# B2              Risotto cremoso con champiñones frescos
# C3    Postre clásico italiano con capas de bizcocho ...
# D4    Pan dulce navideño italiano con frutas confita...
# E5    Pequeñas pastas con forma de orecchiette ideal...
# F6    Harina de maíz italiana para preparar la tradi...
# G7      Mozzarella fresca elaborada con leche de búfala
# J10   Arroz de grano corto perfecto para risottos it...
# K11   Café espresso italiano con un aroma y sabor in...
# L12                 Sardinas frescas en aceite de oliva
# N14                          Gnocchi de patata italiana
# O15    Raviolis rellenos de ricotta y espinacas frescas
# Q17             Deliciosa pasta de trigo durum italiana
# R18             Elaborada con tomates italianos maduros
# S19   Aceite de oliva prensado en frío de las mejore...
# T20                            El famoso queso italiano
# U21   Salami de cerdo italiano curado con hierbas y ...
# W23    Gelato italiano cremoso con sabor a limón fresco
# X24   Postre siciliano con masa crujiente rellena de...
# Y25   Salchichas de cerdo condimentadas con hierbas ...
# GG33  Plato de pasta tradicional de Apulia con garba...
#
#                                             descripción
# A1                        mozzarella fresca y albahaca.
# B2         una delicia italiana para disfrutar en casa.
# C3                         mascarpone y cacao en polvo.
# D4                     un regalo tradicional en Italia.
# E5                                                  NaN
# F6                        perfecta como acompañamiento.
# G7                      suave y deliciosamente cremosa.
# J10             absorbe los sabores de forma exquisita.
# K11        la esencia de la cultura del café en Italia.
# L12                    un bocado delicioso y saludable.
# N14                ideales con salsa de tomate o crema.
# O15                             simplemente deliciosos.
# Q17           ideal para platos de pasta tradicionales.
# R18    una receta tradicional que realza el sabor de...
# S19                   perfecto para aderezos y cocinar.
# T20    madurado durante meses para obtener su sabor ...
# U21    un acompañamiento perfecto para tablas de emb...
# W23                  un postre refrescante y delicioso.
# X24                            una delicia tradicional.
# Y25                          perfectas para aperitivos.
# GG33                             una combinación única.

# %%
def exploracion_dataframe(dataframe):

    #Nos enseña los duplicados en el DF
    print(f"Tenemos {dataframe.duplicated().sum()} duplicados en el conjunto de datos.")
    print("\n ----- \n")
    
    
    #Nos muestra un DataFrame para los valores nulos
    print("Los nulos que tenemos en el conjunto de datos son:")
    df_nulos = pd.DataFrame(dataframe.isnull().sum() / dataframe.shape[0] * 100, columns = ["%_nulos"])
    display(df_nulos[df_nulos["%_nulos"] > 0])
    
    print("\n ----- \n")
    #Nos muestra los tipos de columnas
    print(f"Los tipos de las columnas son:")
    display(pd.DataFrame(dataframe.dtypes, columns = ["tipo_dato"]))
    
    
    print("\n ----- \n")
    #Nos muestra los valores de las columnas categóricas
    print("Los valores que tenemos para las COLUMNAS CATEGÓRICAS son: ")
    dataframe_categoricas = dataframe.select_dtypes(include = "O")
    
    for col in dataframe_categoricas.columns:
        print(f"La columna {col.upper()} tiene las siguientes valores únicos:")
        display(pd.DataFrame(dataframe[col].value_counts()).head())    
    
    #Sacamos los principales estadísticos de cada una de las categorías

    columnas_numericas = dataframe.select_dtypes(include=['int', 'float']).columns
    columnas_categoricas = dataframe.select_dtypes(include='O').columns

    for col in columnas_categoricas:
        print("\n ----- \n")
        print(f"Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el {col.upper()} son: ")
        display(dataframe[[col]].describe().T)

    for col in columnas_numericas:
        print("\n ----- \n")
        print(f"Los principales estadísticos de las COLUMNAS NUMÉRICAS para el {col.upper()} son: ")
        display(dataframe[[col]].describe().T)

# %%
exploracion_dataframe(df_clientes)
# Out:
# Tenemos 0 duplicados en el conjunto de datos.
#
#  -----
#
# Los nulos que tenemos en el conjunto de datos son:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  -----
#
# Los tipos de las columnas son:
#            tipo_dato
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# city          object
# country       object
# address       object
#  -----
#
# Los valores que tenemos para las COLUMNAS CATEGÓRICAS son:
# La columna FIRST_NAME tiene las siguientes valores únicos:
#            first_name
# Germain             3
# Em                  3
# Hunt                3
# Moyra               2
# Francoise           2
# La columna LAST_NAME tiene las siguientes valores únicos:
#            last_name
# Bartolini          2
# Bignall            2
# Armatidge          2
# Espinosa           2
# Whitsey            2
# La columna EMAIL tiene las siguientes valores únicos:
#                             email
# desconocido                    27
# cdunsmore0@instagram.com        1
# hrodliffis@com.com              1
# srickesiesie@shop-pro.jp        1
# abasantif@seattletimes.com      1
# La columna GENDER tiene las siguientes valores únicos:
#              gender
# Male            424
# Female          422
# desconocido      77
# Polygender       19
# Genderqueer      15
# La columna CITY tiene las siguientes valores únicos:
#                    city
# desconocido         124
# Madrid               51
# Granada              42
# Palma De Mallorca    41
# Malaga               36
# La columna COUNTRY tiene las siguientes valores únicos:
#              country
# Spain            846
# desconocido      154
# La columna ADDRESS tiene las siguientes valores únicos:
#                           address
# desconocido                    41
# 7 Toban Center                  2
# 076 Rockefeller Crossing        1
# 9 Steensland Pass               1
# 92 Amoth Trail                  1
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el FIRST_NAME son:
#            count unique      top freq
# first_name  1000    940  Germain    3
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el LAST_NAME son:
#           count unique        top freq
# last_name  1000    986  Bartolini    2
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el EMAIL son:
#       count unique          top freq
# email  1000    974  desconocido   27
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el GENDER son:
#        count unique   top freq
# gender  1000      9  Male  424
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el CITY son:
#      count unique          top freq
# city  1000     56  desconocido  124
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el COUNTRY son:
#         count unique    top freq
# country  1000      2  Spain  846
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el ADDRESS son:
#         count unique          top freq
# address  1000    959  desconocido   41
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el ID son:
#      count   mean         std  min     25%    50%     75%     max
# id  1000.0  500.5  288.819436  1.0  250.75  500.5  750.25  1000.0

# %%
def imputar_nulos(dataframe):
    for col in dataframe.columns:
        dataframe[col] = dataframe[col].fillna('desconocido')

    print("Después del reemplazo usando 'fillna' quedan los siguientes nulos")
    print(dataframe.isnull().sum())

# %%
imputar_nulos(df_clientes)
# Out:
# Después del reemplazo usando 'fillna' quedan los siguientes nulos
# id            0
# first_name    0
# last_name     0
# email         0
# gender        0
# city          0
# country       0
# address       0
# dtype: int64

# %%
imputar_nulos(df_productos)
# Out:
# Después del reemplazo usando 'fillna' quedan los siguientes nulos
# id                 0
# nombre_producto    0
# categoría          0
# precio             0
# origen             0
# descripción        0
# dtype: int64

# %%
def guardado(dataframe, nombre):
    try:
        dataframe.to_csv(f'files/{nombre}_limpio.csv')
        print('El dataframe ha sido guardado con éxito.')
    except Exception as e:
        print(f'Error en el guardado: {e}')

# %%
guardado(df_clientes, 'clientes')
guardado(df_ventas, 'ventas')
guardado(df_productos, 'productos')
# Out:
# El dataframe ha sido guardado con éxito.
# El dataframe ha sido guardado con éxito.
# El dataframe ha sido guardado con éxito.

# %% [markdown]
# ---------

# %%
df_merge = df_clientes.merge( right=df_ventas, how='left',
                        left_on='id', right_on='id_cliente')

df_merge.sample(10)
# Out:
#        id first_name  last_name                        email       gender  \
# 643   604      Abdel     Harlow        aharlowgr@harvard.edu         Male
# 620   581     Leeann     Kasbye     lkasbyeg4@purevolume.com       Female
# 701   660    Johnath   Rainsdon      jrainsdonib@godaddy.com       Female
# 1039  983  Margareta  MacArthur      mmacarthurra@weebly.com  Genderfluid
# 1030  974       Luke     Insley            linsleyr1@ftc.gov         Male
# 188   188       Tove   Aldridge  taldridge57@theguardian.com       Female
# 401   377     Janith      Brunt        jbruntag@marriott.com       Female
# 132   132      Neely   Maggiore   nmaggiore3n@thetimes.co.uk  Genderfluid
# 1031  975      Dasya   Althrope      dalthroper2@yahoo.co.jp       Female
# 1002  946     Gannie    Jaffrey  gjaffreyq9@miitbeian.gov.cn         Male
#
#                              city      country                address  \
# 643                       Sevilla        Spain        2 Spohn Parkway
# 620         Sant Cugat Del Valles        Spain        2 Oriole Street
# 701                     Santander        Spain   6 John Wall Junction
# 1039                     Valencia        Spain      5 Park Meadow Way
# 1030               Pamplona/Iruña        Spain            desconocido
# 188                       Granada  desconocido       01361 Utah Trail
# 401                    Valladolid        Spain       5482 Huxley Park
# 132                   desconocido        Spain  652 Sachtjen Crossing
# 1031  Palmas De Gran Canaria, Las        Spain     22119 Artisan Lane
# 1002                       Murcia        Spain    370 Arrowood Center
#
#       id_cliente id_producto fecha_venta  cantidad  total
# 643          NaN         NaN         NaN       NaN    NaN
# 620          NaN         NaN         NaN       NaN    NaN
# 701          NaN         NaN         NaN       NaN    NaN
# 1039         NaN         NaN         NaN       NaN    NaN
# 1030         NaN         NaN         NaN       NaN    NaN
# 188          NaN         NaN         NaN       NaN    NaN
# 401          NaN         NaN         NaN       NaN    NaN
# 132          NaN         NaN         NaN       NaN    NaN
# 1031         NaN         NaN         NaN       NaN    NaN
# 1002         NaN         NaN         NaN       NaN    NaN

# %%
df_merge
# Out:
#         id  first_name last_name                         email       gender  \
# 0        1       Cheri  Dunsmore      cdunsmore0@instagram.com       Female
# 1        2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au         Male
# 2        3  Michaeline   Paynton            mpaynton2@narod.ru       Female
# 3        4      Filmer    Eirwin            feirwin3@intel.com  desconocido
# 4        5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com       Female
# ...    ...         ...       ...                           ...          ...
# 1065   996         Ray    Tarpey      rtarpeyrn@bravesites.com       Female
# 1066   997        Flem  Roderham       froderhamro@dropbox.com         Male
# 1067   998   Winifield    Blakes         wblakesrp@jiathis.com         Male
# 1068   999      Lanita  Espinosa        lespinosarq@discuz.net       Female
# 1069  1000     Grissel   Siberry     gsiberryrr@wikispaces.com       Female
#
#                              city country                   address  \
# 0               Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                            Lugo   Spain        0046 Utah Junction
# 2                     desconocido   Spain          0 Corry Crossing
# 3                            Leon   Spain       5 American Ash Road
# 4     Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# ...                           ...     ...                       ...
# 1065                       Zamora   Spain     36384 Sommers Terrace
# 1066                   Pontevedra   Spain    93177 Eastwood Parkway
# 1067                         Vigo   Spain       03044 Grayhawk Road
# 1068                 Dos Hermanas   Spain        2 Schmedeman Drive
# 1069                         Leon   Spain     42274 Waywood Terrace
#
#       id_cliente id_producto fecha_venta  cantidad  total
# 0            NaN         NaN         NaN       NaN    NaN
# 1            NaN         NaN         NaN       NaN    NaN
# 2            NaN         NaN         NaN       NaN    NaN
# 3            NaN         NaN         NaN       NaN    NaN
# 4            NaN         NaN         NaN       NaN    NaN
# ...          ...         ...         ...       ...    ...
# 1065         NaN         NaN         NaN       NaN    NaN
# 1066         NaN         NaN         NaN       NaN    NaN
# 1067         NaN         NaN         NaN       NaN    NaN
# 1068         NaN         NaN         NaN       NaN    NaN
# 1069         NaN         NaN         NaN       NaN    NaN
#
# [1070 rows x 13 columns]

# %%
df_productos = df_productos.reset_index()
df_productos = df_productos.rename(columns={'index':'id_producto'})
df_productos
# Out:
#    id_producto                              id       nombre_producto  \
# 0           A1                Pizza Margherita     Platos Preparados
# 1           B2          Risotto de Champiñones     Platos Preparados
# 2           C3                        Tiramisú               Postres
# 3           D4                       Panettone            Repostería
# 4           E5                     Orecchiette       Productos Secos
# 5           F6             Polenta Tradicional               Harinas
# 6           G7            Mozzarella di Bufala     Productos Lácteos
# 7          J10                   Arroz Arborio       Productos Secos
# 8          K11                   Café Espresso                  Café
# 9          L12     Sardinas en Aceite de Oliva  Pescados en Conserva
# 10         N14               Gnocchi de Patata  Productos Congelados
# 11         O15  Ravioli de Ricotta y Espinacas  Productos Congelados
# 12         Q17                  Pasta de Trigo       Productos Secos
# 13         R18          Salsa de Tomate Casera                Salsas
# 14         S19    Aceite de Oliva Virgen Extra               Aceites
# 15         T20                 Queso Parmesano     Productos Lácteos
# 16         U21                  Salami Toscano             Embutidos
# 17         W23                 Gelato de Limón               Helados
# 18         X24                         Cannoli                Dulces
# 19         Y25                      Cacciatore             Embutidos
# 20        GG33                   Ciceri e Tria     Platos Preparados
#
#     categoría  precio                                             origen  \
# 0        8.99  Italia                  Clásica pizza italiana con tomate
# 1        6.75  Italia            Risotto cremoso con champiñones frescos
# 2        5.49  Italia  Postre clásico italiano con capas de bizcocho ...
# 3       10.99  Italia  Pan dulce navideño italiano con frutas confita...
# 4        4.29  Italia  Pequeñas pastas con forma de orecchiette ideal...
# 5        3.75  Italia  Harina de maíz italiana para preparar la tradi...
# 6        9.25  Italia    Mozzarella fresca elaborada con leche de búfala
# 7        4.89  Italia  Arroz de grano corto perfecto para risottos it...
# 8        6.49  Italia  Café espresso italiano con un aroma y sabor in...
# 9        3.99  Italia                Sardinas frescas en aceite de oliva
# 10       5.25  Italia                         Gnocchi de patata italiana
# 11       6.75  Italia   Raviolis rellenos de ricotta y espinacas frescas
# 12       3.99  Italia            Deliciosa pasta de trigo durum italiana
# 13       2.49  Italia            Elaborada con tomates italianos maduros
# 14       9.99  Italia  Aceite de oliva prensado en frío de las mejore...
# 15       7.89  Italia                           El famoso queso italiano
# 16       5.75  Italia  Salami de cerdo italiano curado con hierbas y ...
# 17       4.25  Italia   Gelato italiano cremoso con sabor a limón fresco
# 18       3.99  Italia  Postre siciliano con masa crujiente rellena de...
# 19       6.75  Italia  Salchichas de cerdo condimentadas con hierbas ...
# 20       5.89  Italia  Plato de pasta tradicional de Apulia con garba...
#
#                                           descripción
# 0                       mozzarella fresca y albahaca.
# 1        una delicia italiana para disfrutar en casa.
# 2                        mascarpone y cacao en polvo.
# 3                    un regalo tradicional en Italia.
# 4                                         desconocido
# 5                       perfecta como acompañamiento.
# 6                     suave y deliciosamente cremosa.
# 7             absorbe los sabores de forma exquisita.
# 8        la esencia de la cultura del café en Italia.
# 9                    un bocado delicioso y saludable.
# 10               ideales con salsa de tomate o crema.
# 11                            simplemente deliciosos.
# 12          ideal para platos de pasta tradicionales.
# 13   una receta tradicional que realza el sabor de...
# 14                  perfecto para aderezos y cocinar.
# 15   madurado durante meses para obtener su sabor ...
# 16   un acompañamiento perfecto para tablas de emb...
# 17                 un postre refrescante y delicioso.
# 18                           una delicia tradicional.
# 19                         perfectas para aperitivos.
# 20                             una combinación única.

# %%
df_unido = df_merge.merge( right=df_productos, how='left',
                        left_on='id_producto', right_on='id_producto')

df_unido.sample(10)
# Out:
#       id_x first_name   last_name                         email       gender  \
# 674    635     Dehlia  Vedishchev       dvedishchevhm@wiley.com       Female
# 263    243     Laurie     Harlowe      lharlowe6q@csmonitor.com  desconocido
# 521    496    Pinchas       Rains        prainsdr@moonfruit.com         Male
# 167    167    Lorelei  Verheijden       lverheijden4m@vimeo.com       Female
# 446    422     Dwight  Rottenbury       drottenburybp@umich.edu         Male
# 1026   970       Niki      Bonsey   nbonseyqx@deliciousdays.com  desconocido
# 734    693     Taylor      Dafydd  tdafyddj8@chicagotribune.com         Male
# 996    940     Burlie   Waterhous     bwaterhousq3@cbslocal.com         Male
# 316    296    Lindsay     Gosling        lgosling87@twitpic.com       Female
# 1045   987      Cecil       Hemms     chemmsre@reverbnation.com         Male
#
#                         city      country                 address  id_cliente  \
# 674   Donostia-San Sebastian  desconocido   291 Oak Valley Circle         NaN
# 263                    Ceuta        Spain             desconocido         NaN
# 521                   Lleida  desconocido           396 1st Trail         NaN
# 167           Pamplona/Iruña  desconocido     09188 Prentice Park         NaN
# 446              desconocido        Spain        5 Stephen Avenue         NaN
# 1026               Barcelona        Spain  3045 Goodland Crossing         NaN
# 734                Salamanca        Spain      82 Westport Center         NaN
# 996               Valladolid        Spain      78 Gulseth Parkway         NaN
# 316                Salamanca        Spain        8783 Main Circle         NaN
# 1045             desconocido        Spain    1737 Commercial Lane       987.0
#
#      id_producto fecha_venta  cantidad  total id_y nombre_producto  categoría  \
# 674          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 263          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 521          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 167          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 446          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 1026         NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 734          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 996          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 316          NaN         NaN       NaN    NaN  NaN             NaN        NaN
# 1045        BR86  2023-10-24       1.0   5.25  NaN             NaN        NaN
#
#      precio origen descripción
# 674     NaN    NaN         NaN
# 263     NaN    NaN         NaN
# 521     NaN    NaN         NaN
# 167     NaN    NaN         NaN
# 446     NaN    NaN         NaN
# 1026    NaN    NaN         NaN
# 734     NaN    NaN         NaN
# 996     NaN    NaN         NaN
# 316     NaN    NaN         NaN
# 1045    NaN    NaN         NaN

# %%
df_sin_nulos = df_unido.dropna()

# %%
df_sin_nulos
# Out:
#      id_x first_name  last_name                              email  \
# 120   121        Wye   Sinncock                wsinncock3c@fc2.com
# 170   170     Brigit       Witt                     bwitt4p@va.gov
# 371   347     Egbert   Leborgne            eleborgne9m@reuters.com
# 523   498    Padgett    Painter  ppainterdt@scientificamerican.com
# 658   619      Nicky    Bernier             nbernierh6@4shared.com
# 764   723    Sephira  Bleackley       sbleackleyk2@liveinternet.ru
# 857   812      Quinn    Brenton       qbrentonmj@blogtalkradio.com
# 940   885    Windham     Badham                wbadhamok@wired.com
#
#           gender                         city      country  \
# 120         Male                    Santander  desconocido
# 170       Female                 Dos Hermanas        Spain
# 371         Male                      Sevilla        Spain
# 523         Male                    Barcelona        Spain
# 658      Agender                   Valladolid        Spain
# 764  desconocido                       Girona  desconocido
# 857       Female                        Gijon        Spain
# 940         Male  Hospitalet De Llobregat, L'        Spain
#
#                     address  id_cliente id_producto fecha_venta  cantidad  \
# 120    4679 Fair Oaks Trail       121.0          D4  2023-11-20       3.0
# 170           38 Ohio Point       170.0         U21  2023-11-15       1.0
# 371            7 Quincy Way       347.0         Q17  2023-11-18       2.0
# 523          5 Artisan Lane       498.0          C3  2023-11-21       1.0
# 658        55 Waubesa Trail       619.0         T20  2023-11-17       1.0
# 764        4 Birchwood Road       723.0          A1  2023-11-22       2.0
# 857  5495 Lakeland Junction       812.0         Y25  2023-11-16       2.0
# 940      68 Nelson Junction       885.0         L12  2023-11-19       1.0
#
#      total                         id_y       nombre_producto  categoría  \
# 120  32.97                    Panettone            Repostería      10.99
# 170   5.75               Salami Toscano             Embutidos       5.75
# 371   7.98               Pasta de Trigo       Productos Secos       3.99
# 523   5.49                     Tiramisú               Postres       5.49
# 658   7.89              Queso Parmesano     Productos Lácteos       7.89
# 764  17.98             Pizza Margherita     Platos Preparados       8.99
# 857  13.50                   Cacciatore             Embutidos       6.75
# 940   6.49  Sardinas en Aceite de Oliva  Pescados en Conserva       3.99
#
#      precio                                             origen  \
# 120  Italia  Pan dulce navideño italiano con frutas confita...
# 170  Italia  Salami de cerdo italiano curado con hierbas y ...
# 371  Italia            Deliciosa pasta de trigo durum italiana
# 523  Italia  Postre clásico italiano con capas de bizcocho ...
# 658  Italia                           El famoso queso italiano
# 764  Italia                  Clásica pizza italiana con tomate
# 857  Italia  Salchichas de cerdo condimentadas con hierbas ...
# 940  Italia                Sardinas frescas en aceite de oliva
#
#                                            descripción
# 120                   un regalo tradicional en Italia.
# 170   un acompañamiento perfecto para tablas de emb...
# 371          ideal para platos de pasta tradicionales.
# 523                       mascarpone y cacao en polvo.
# 658   madurado durante meses para obtener su sabor ...
# 764                      mozzarella fresca y albahaca.
# 857                         perfectas para aperitivos.
# 940                   un bocado delicioso y saludable.
